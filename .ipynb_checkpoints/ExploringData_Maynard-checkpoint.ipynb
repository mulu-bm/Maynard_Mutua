# %%
import pandas as pd
import numpy as np
import requests

# %%
r = requests.get('http://api.cal-adapt.org/api/')

# %%
r.json()
# Out:
# {'ccc4aregions': 'https://api.cal-adapt.org/api/ccc4aregions/',
#  'cdistricts': 'https://api.cal-adapt.org/api/cdistricts/',
#  'censustracts': 'https://api.cal-adapt.org/api/censustracts/',
#  'climregions': 'https://api.cal-adapt.org/api/climregions/',
#  'counties': 'https://api.cal-adapt.org/api/counties/',
#  'datasets': 'https://api.cal-adapt.org/api/datasets/',
#  'electricutilities': 'https://api.cal-adapt.org/api/electricutilities/',
#  'evtlocations': 'https://api.cal-adapt.org/api/evtlocations/',
#  'hadisdstations': 'https://api.cal-adapt.org/api/hadisdstations/',
#  'hydrounits': 'https://api.cal-adapt.org/api/hydrounits/',
#  'irwm': 'https://api.cal-adapt.org/api/irwm/',
#  'locagrid': 'https://api.cal-adapt.org/api/locagrid/',
#  'place': 'https://api.cal-adapt.org/api/place/',
#  'rstores': 'https://api.cal-adapt.org/api/rstores/',
#  'series': 'https://api.cal-adapt.org/api/series/',
#  'states': 'https://api.cal-adapt.org/api/states/',
# ...

# %%
series = r = requests.get('http://api.cal-adapt.org/api/series')
series.json()
# Out:
# {'count': 935,
#  'next': 'https://api.cal-adapt.org/api/series/?page=2',
#  'previous': None,
#  'results': [{'name': 'LOCA VIC drought daily baseflow HadGEM2-ES RCP 8.5 early century',
#    'slug': 'baseflow_day_drought_HadGEM2-ES_rcp85_early_century',
#    'url': 'https://api.cal-adapt.org/api/series/baseflow_day_drought_HadGEM2-ES_rcp85_early_century/',
#    'begin': '2018-01-01T00:00:00Z',
#    'end': '2046-12-31T00:00:00Z',
#    'rasters': ['https://api.cal-adapt.org/api/rstores/baseflow_day_drought_HadGEM2-ES_rcp85_2018-2046/'],
#    'tres': 'daily'},
#   {'name': 'LOCA VIC drought daily baseflow HadGEM2-ES RCP 8.5 late century',
#    'slug': 'baseflow_day_drought_HadGEM2-ES_rcp85_late_century',
#    'url': 'https://api.cal-adapt.org/api/series/baseflow_day_drought_HadGEM2-ES_rcp85_late_century/',
#    'begin': '2046-01-01T00:00:00Z',
#    'end': '2074-12-31T00:00:00Z',
#    'rasters': ['https://api.cal-adapt.org/api/rstores/baseflow_day_drought_HadGEM2-ES_rcp85_2046-2074/'],
# ...
